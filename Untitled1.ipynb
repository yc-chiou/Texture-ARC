# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

resolution = 40   # pixels/μm

Si = mp.Medium(index=3.45)

dpml = 1.0
pml_layers = [mp.PML(dpml)]

sx = 5
sy = 3
cell = mp.Vector3(sx+2*dpml,sy+2*dpml,0)

a = 1.0     # waveguide width/height

k_point = mp.Vector3(z=0.5)

def parallel_waveguide(s,xodd):
    geometry = [mp.Block(center=mp.Vector3(-0.5*(s+a)),
                         size=mp.Vector3(a,a,mp.inf),
                         material=Si),
                mp.Block(center=mp.Vector3(0.5*(s+a)),
                         size=mp.Vector3(a,a,mp.inf),
                         material=Si)]

    symmetries = [mp.Mirror(mp.X, phase=-1 if xodd else 1),
                  mp.Mirror(mp.Y, phase=-1)]

    sim = mp.Simulation(resolution=resolution,
                        cell_size=cell,
                        geometry=geometry,
                        boundary_layers=pml_layers,
                        symmetries=symmetries,
                        k_point=k_point)

    sim.init_sim()
    EigenmodeData = sim.get_eigenmode(0.22,
                                      mp.Z,
                                      mp.Volume(center=mp.Vector3(), size=mp.Vector3(sx,sy)),
                                      2 if xodd else 1,
                                      k_point,
                                      match_frequency=False,
                                      parity=mp.ODD_Y)

    fcen = EigenmodeData.freq
    print("freq:, {}, {}, {}".format("xodd" if xodd else "xeven", s, fcen))

    sim.reset_meep()

    eig_sources = [mp.EigenModeSource(src=mp.GaussianSource(fcen, fwidth=0.1*fcen),
                                      size=mp.Vector3(sx,sy),
                                      center=mp.Vector3(),
                                      eig_band=2 if xodd else 1,
                                      eig_kpoint=k_point,
                                      eig_match_freq=False,
                                      eig_parity=mp.ODD_Y)]

    sim.change_sources(eig_sources)

    flux_reg = mp.FluxRegion(direction=mp.Z, center=mp.Vector3(), size=mp.Vector3(sx,sy))
    wvg_flux = sim.add_flux(fcen, 0, 1, flux_reg)

    force_reg1 = mp.ForceRegion(mp.Vector3(0.49*s), direction=mp.X, weight=1, size=mp.Vector3(y=sy))
    force_reg2 = mp.ForceRegion(mp.Vector3(0.5*s+1.01*a), direction=mp.X, weight=-1, size=mp.Vector3(y=sy))
    wvg_force = sim.add_force(fcen, 0, 1, force_reg1, force_reg2)

    sim.run(until_after_sources=1500)

    flux = mp.get_fluxes(wvg_flux)[0]
    force = mp.get_forces(wvg_force)[0]
    print("data:, {}, {}, {}, {}, {}".format("xodd" if xodd else "xeven", s, flux, force, -force/flux))

    sim.reset_meep()
    return flux, force
# Out:
# Using MPI version 3.1, 1 processes

# %%
s = np.arange(0.05,1.05,0.05)
fluxes_odd = np.zeros(s.size)
forces_odd = np.zeros(s.size)
fluxes_even = np.zeros(s.size)
forces_even = np.zeros(s.size)

for k in range(len(s)):
    fluxes_odd[k], forces_odd[k] = parallel_waveguide(s[k],True)
    fluxes_even[k], forces_even[k] = parallel_waveguide(s[k],False)

plt.figure(dpi=150)
plt.plot(s,-forces_odd/fluxes_odd,'rs',label='anti-symmetric')
plt.plot(s,-forces_even/fluxes_even,'bo',label='symmetric')
plt.grid(True)
plt.xlabel('waveguide separation s/a')
plt.ylabel('optical force (F/L)(ac/P)')
plt.legend(loc='upper right')
plt.show()
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00120997 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0215051 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.235389 after 27 iters
# Dominant planewave for band 2: (-0.400000,0.000000,0.500000)
# freq:, xodd, 0.05, 0.23538931364680266
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00138903 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0415199 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.235389 after 27 iters
# FloatProgress(value=0.0, description='0% done ', max=1924.828125)
# Meep progress: 76.275/1924.828125 = 4.0% done in 4.0s, 96.9s to go
# on time step 6117 (time=76.4625), 0.000653979 s/step
# Meep progress: 151.875/1924.828125 = 7.9% done in 8.0s, 93.4s to go
# on time step 12164 (time=152.05), 0.000661518 s/step
# Meep progress: 224.95000000000002/1924.828125 = 11.7% done in 12.0s, 90.7s to go
# on time step 18011 (time=225.138), 0.000684174 s/step
# Meep progress: 298.0625/1924.828125 = 15.5% done in 16.0s, 87.3s to go
# on time step 23860 (time=298.25), 0.000683916 s/step
# Meep progress: 371.20000000000005/1924.828125 = 19.3% done in 20.0s, 83.7s to go
# on time step 29711 (time=371.388), 0.000683646 s/step
# Meep progress: 444.40000000000003/1924.828125 = 23.1% done in 24.0s, 80.0s to go
# on time step 35568 (time=444.6), 0.000683052 s/step
# Meep progress: 517.7625/1924.828125 = 26.9% done in 28.0s, 76.1s to go
# on time step 41437 (time=517.962), 0.000681575 s/step
# Meep progress: 591.1/1924.828125 = 30.7% done in 32.0s, 72.2s to go
# on time step 47305 (time=591.312), 0.000681737 s/step
# Meep progress: 664.5500000000001/1924.828125 = 34.5% done in 36.0s, 68.3s to go
# on time step 53181 (time=664.763), 0.000680789 s/step
# Meep progress: 737.625/1924.828125 = 38.3% done in 40.0s, 64.4s to go
# on time step 59028 (time=737.85), 0.000684225 s/step
# Meep progress: 810.75/1924.828125 = 42.1% done in 44.0s, 60.5s to go
# on time step 64879 (time=810.988), 0.000683718 s/step
# Meep progress: 884.0125/1924.828125 = 45.9% done in 48.0s, 56.5s to go
# on time step 70741 (time=884.263), 0.000682434 s/step
# Meep progress: 957.4250000000001/1924.828125 = 49.7% done in 52.0s, 52.5s to go
# on time step 76614 (time=957.675), 0.000681115 s/step
# Meep progress: 1030.7250000000001/1924.828125 = 53.5% done in 56.0s, 48.6s to go
# on time step 82478 (time=1030.98), 0.000682157 s/step
# Meep progress: 1104.0125/1924.828125 = 57.4% done in 60.0s, 44.6s to go
# on time step 88342 (time=1104.28), 0.000682169 s/step
# Meep progress: 1177.4750000000001/1924.828125 = 61.2% done in 64.0s, 40.6s to go
# on time step 94219 (time=1177.74), 0.000680681 s/step
# Meep progress: 1250.625/1924.828125 = 65.0% done in 68.0s, 36.7s to go
# on time step 100072 (time=1250.9), 0.000683504 s/step
# Meep progress: 1323.5500000000002/1924.828125 = 68.8% done in 72.0s, 32.7s to go
# on time step 105907 (time=1323.84), 0.000685554 s/step
# Meep progress: 1396.9625/1924.828125 = 72.6% done in 76.0s, 28.7s to go
# on time step 111780 (time=1397.25), 0.000681144 s/step
# Meep progress: 1470.1875/1924.828125 = 76.4% done in 80.0s, 24.7s to go
# on time step 117639 (time=1470.49), 0.000682825 s/step
# Meep progress: 1543.4125000000001/1924.828125 = 80.2% done in 84.0s, 20.8s to go
# on time step 123497 (time=1543.71), 0.00068286 s/step
# Meep progress: 1616.6875/1924.828125 = 84.0% done in 88.0s, 16.8s to go
# on time step 129359 (time=1616.99), 0.000682374 s/step
# Meep progress: 1689.775/1924.828125 = 87.8% done in 92.0s, 12.8s to go
# on time step 135207 (time=1690.09), 0.00068401 s/step
# Meep progress: 1763.1875/1924.828125 = 91.6% done in 96.0s, 8.8s to go
# on time step 141080 (time=1763.5), 0.000681129 s/step
# Meep progress: 1836.6625000000001/1924.828125 = 95.4% done in 100.0s, 4.8s to go
# on time step 146959 (time=1836.99), 0.000680409 s/step
# Meep progress: 1909.8375/1924.828125 = 99.2% done in 104.0s, 0.8s to go
# on time step 152813 (time=1910.16), 0.000683356 s/step
# run 0 finished at t = 1924.8375 (153987 timesteps)
# data:, xodd, 0.05, 29280159.602458976, -11805855.062221173, 0.40320323463092417
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000777006 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0156908 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.213015 after 30 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.05, 0.21301453307406013
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00213408 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0333619 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.213015 after 30 iters
# FloatProgress(value=0.0, description='0% done ', max=1969.4515380859375)
# Meep progress: 70.7625/1969.4515380859375 = 3.6% done in 4.0s, 107.3s to go
# on time step 5681 (time=71.0125), 0.000704111 s/step
# Meep progress: 143.7375/1969.4515380859375 = 7.3% done in 8.0s, 101.6s to go
# on time step 11520 (time=144), 0.000685136 s/step
# Meep progress: 216.525/1969.4515380859375 = 11.0% done in 12.0s, 97.2s to go
# on time step 17344 (time=216.8), 0.000686888 s/step
# Meep progress: 289.1375/1969.4515380859375 = 14.7% done in 16.0s, 93.0s to go
# on time step 23154 (time=289.425), 0.000688522 s/step
# Meep progress: 361.9375/1969.4515380859375 = 18.4% done in 20.0s, 88.8s to go
# on time step 28973 (time=362.163), 0.000687444 s/step
# Meep progress: 434.425/1969.4515380859375 = 22.1% done in 24.0s, 84.8s to go
# on time step 34777 (time=434.713), 0.000689209 s/step
# Meep progress: 507.175/1969.4515380859375 = 25.8% done in 28.0s, 80.7s to go
# on time step 40598 (time=507.475), 0.00068726 s/step
# Meep progress: 579.95/1969.4515380859375 = 29.4% done in 32.0s, 76.7s to go
# on time step 46421 (time=580.263), 0.000686993 s/step
# Meep progress: 653.2/1969.4515380859375 = 33.2% done in 36.0s, 72.5s to go
# on time step 52281 (time=653.513), 0.000682686 s/step
# Meep progress: 727.225/1969.4515380859375 = 36.9% done in 40.0s, 68.3s to go
# on time step 58204 (time=727.55), 0.000675383 s/step
# Meep progress: 801.1500000000001/1969.4515380859375 = 40.7% done in 44.0s, 64.2s to go
# on time step 64118 (time=801.475), 0.0006764 s/step
# Meep progress: 875.0875000000001/1969.4515380859375 = 44.4% done in 48.0s, 60.0s to go
# on time step 70033 (time=875.413), 0.000676274 s/step
# Meep progress: 949.0375/1969.4515380859375 = 48.2% done in 52.0s, 55.9s to go
# on time step 75950 (time=949.375), 0.000676038 s/step
# Meep progress: 1022.85/1969.4515380859375 = 51.9% done in 56.0s, 51.8s to go
# on time step 81855 (time=1023.19), 0.000677481 s/step
# Meep progress: 1096.7625/1969.4515380859375 = 55.7% done in 60.0s, 47.7s to go
# on time step 87769 (time=1097.11), 0.000676416 s/step
# Meep progress: 1170.6875/1969.4515380859375 = 59.4% done in 64.0s, 43.7s to go
# on time step 93684 (time=1171.05), 0.000676305 s/step
# Meep progress: 1244.4125000000001/1969.4515380859375 = 63.2% done in 68.0s, 39.6s to go
# on time step 99581 (time=1244.76), 0.000678312 s/step
# Meep progress: 1317.2/1969.4515380859375 = 66.9% done in 72.0s, 35.7s to go
# on time step 105402 (time=1317.53), 0.000687264 s/step
# Meep progress: 1390.4250000000002/1969.4515380859375 = 70.6% done in 76.0s, 31.7s to go
# on time step 111262 (time=1390.78), 0.000682642 s/step
# Meep progress: 1464.375/1969.4515380859375 = 74.4% done in 80.0s, 27.6s to go
# on time step 117181 (time=1464.76), 0.000675896 s/step
# Meep progress: 1538.4125000000001/1969.4515380859375 = 78.1% done in 84.0s, 23.5s to go
# on time step 123104 (time=1538.8), 0.000675355 s/step
# Meep progress: 1612.1375/1969.4515380859375 = 81.9% done in 88.0s, 19.5s to go
# on time step 129002 (time=1612.53), 0.00067822 s/step
# Meep progress: 1686.1375/1969.4515380859375 = 85.6% done in 92.0s, 15.5s to go
# on time step 134922 (time=1686.53), 0.000675697 s/step
# Meep progress: 1760.025/1969.4515380859375 = 89.4% done in 96.0s, 11.4s to go
# on time step 140833 (time=1760.41), 0.000676711 s/step
# Meep progress: 1834.0625/1969.4515380859375 = 93.1% done in 100.0s, 7.4s to go
# on time step 146757 (time=1834.46), 0.000675301 s/step
# Meep progress: 1908.2375000000002/1969.4515380859375 = 96.9% done in 104.0s, 3.3s to go
# on time step 152691 (time=1908.64), 0.000674112 s/step
# run 0 finished at t = 1969.4625 (157557 timesteps)
# data:, xeven, 0.05, 21340662.500055127, 24949183.11242699, -1.1690913115917811
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000683784 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.015475 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.234644 after 27 iters
# Dominant planewave for band 2: (0.200000,-0.000000,0.500000)
# freq:, xodd, 0.1, 0.2346440279427558
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00232816 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.032371 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.234644 after 27 iters
# FloatProgress(value=0.0, description='0% done ', max=1926.177490234375)
# Meep progress: 72.53750000000001/1926.177490234375 = 3.8% done in 4.0s, 102.2s to go
# on time step 5825 (time=72.8125), 0.000686789 s/step
# Meep progress: 146.95000000000002/1926.177490234375 = 7.6% done in 8.0s, 96.9s to go
# on time step 11779 (time=147.238), 0.000671917 s/step
# Meep progress: 221.4625/1926.177490234375 = 11.5% done in 12.0s, 92.4s to go
# on time step 17740 (time=221.75), 0.00067107 s/step
# Meep progress: 295.925/1926.177490234375 = 15.4% done in 16.0s, 88.2s to go
# on time step 23698 (time=296.225), 0.000671466 s/step
# Meep progress: 370.225/1926.177490234375 = 19.2% done in 20.0s, 84.1s to go
# on time step 29642 (time=370.525), 0.000672969 s/step
# Meep progress: 444.4375/1926.177490234375 = 23.1% done in 24.0s, 80.0s to go
# on time step 35579 (time=444.738), 0.000673781 s/step
# Meep progress: 518.5500000000001/1926.177490234375 = 26.9% done in 28.0s, 76.0s to go
# on time step 41509 (time=518.863), 0.000674626 s/step
# Meep progress: 592.8000000000001/1926.177490234375 = 30.8% done in 32.0s, 72.0s to go
# on time step 47450 (time=593.125), 0.000673355 s/step
# Meep progress: 667.1125000000001/1926.177490234375 = 34.6% done in 36.0s, 68.0s to go
# on time step 53396 (time=667.45), 0.000672823 s/step
# Meep progress: 741.6875/1926.177490234375 = 38.5% done in 40.0s, 63.9s to go
# on time step 59363 (time=742.038), 0.000670441 s/step
# Meep progress: 816.225/1926.177490234375 = 42.4% done in 44.0s, 59.8s to go
# on time step 65326 (time=816.575), 0.000670843 s/step
# Meep progress: 890.6500000000001/1926.177490234375 = 46.2% done in 48.0s, 55.8s to go
# on time step 71280 (time=891), 0.00067184 s/step
# Meep progress: 965.2625/1926.177490234375 = 50.1% done in 52.0s, 51.8s to go
# on time step 77250 (time=965.625), 0.000670109 s/step
# Meep progress: 1039.7250000000001/1926.177490234375 = 54.0% done in 56.0s, 47.7s to go
# on time step 83207 (time=1040.09), 0.000671504 s/step
# Meep progress: 1114.25/1926.177490234375 = 57.8% done in 60.0s, 43.7s to go
# on time step 89169 (time=1114.61), 0.000670957 s/step
# Meep progress: 1188.8375/1926.177490234375 = 61.7% done in 64.0s, 39.7s to go
# on time step 95137 (time=1189.21), 0.000670329 s/step
# Meep progress: 1263.0500000000002/1926.177490234375 = 65.6% done in 68.0s, 35.7s to go
# on time step 101075 (time=1263.44), 0.000673716 s/step
# Meep progress: 1337.1375/1926.177490234375 = 69.4% done in 72.0s, 31.7s to go
# on time step 107003 (time=1337.54), 0.000674851 s/step
# Meep progress: 1411.6000000000001/1926.177490234375 = 73.3% done in 76.0s, 27.7s to go
# on time step 112960 (time=1412), 0.000671517 s/step
# Meep progress: 1485.9125000000001/1926.177490234375 = 77.1% done in 80.0s, 23.7s to go
# on time step 118906 (time=1486.33), 0.000672834 s/step
# Meep progress: 1560.3375/1926.177490234375 = 81.0% done in 84.0s, 19.7s to go
# on time step 124861 (time=1560.76), 0.000671777 s/step
# Meep progress: 1634.6875/1926.177490234375 = 84.9% done in 88.0s, 15.7s to go
# on time step 130809 (time=1635.11), 0.000672531 s/step
# Meep progress: 1709.0/1926.177490234375 = 88.7% done in 92.0s, 11.7s to go
# on time step 136754 (time=1709.43), 0.000672848 s/step
# Meep progress: 1783.5125/1926.177490234375 = 92.6% done in 96.0s, 7.7s to go
# on time step 142715 (time=1783.94), 0.000671089 s/step
# Meep progress: 1858.0125/1926.177490234375 = 96.5% done in 100.0s, 3.7s to go
# on time step 148677 (time=1858.46), 0.000671012 s/step
# run 0 finished at t = 1926.1875 (154095 timesteps)
# data:, xodd, 0.1, 28875245.26864422, -13451098.388527226, 0.4658349483574376
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000653982 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0154309 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.215375 after 31 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.1, 0.2153750219683721
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00242209 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.034163 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.215375 after 31 iters
# FloatProgress(value=0.0, description='0% done ', max=1964.306396484375)
# Meep progress: 71.9375/1964.306396484375 = 3.7% done in 4.0s, 105.2s to go
# on time step 5777 (time=72.2125), 0.000692411 s/step
# Meep progress: 146.15/1964.306396484375 = 7.4% done in 8.0s, 99.5s to go
# on time step 11715 (time=146.438), 0.000673691 s/step
# Meep progress: 220.3375/1964.306396484375 = 11.2% done in 12.0s, 95.0s to go
# on time step 17650 (time=220.625), 0.000673989 s/step
# Meep progress: 294.4875/1964.306396484375 = 15.0% done in 16.0s, 90.7s to go
# on time step 23582 (time=294.775), 0.000674359 s/step
# Meep progress: 368.57500000000005/1964.306396484375 = 18.8% done in 20.0s, 86.6s to go
# on time step 29510 (time=368.875), 0.000674862 s/step
# Meep progress: 442.55/1964.306396484375 = 22.5% done in 24.0s, 82.5s to go
# on time step 35428 (time=442.85), 0.000675933 s/step
# Meep progress: 516.575/1964.306396484375 = 26.3% done in 28.0s, 78.5s to go
# on time step 41352 (time=516.9), 0.00067531 s/step
# Meep progress: 590.3625000000001/1964.306396484375 = 30.1% done in 32.0s, 74.5s to go
# on time step 47256 (time=590.7), 0.000677594 s/step
# Meep progress: 664.325/1964.306396484375 = 33.8% done in 36.0s, 70.5s to go
# on time step 53174 (time=664.675), 0.000676004 s/step
# Meep progress: 738.4000000000001/1964.306396484375 = 37.6% done in 40.0s, 66.4s to go
# on time step 59100 (time=738.75), 0.000675037 s/step
# Meep progress: 812.5125/1964.306396484375 = 41.4% done in 44.0s, 62.4s to go
# on time step 65029 (time=812.863), 0.000674737 s/step
# Meep progress: 886.85/1964.306396484375 = 45.1% done in 48.0s, 58.3s to go
# on time step 70978 (time=887.225), 0.00067247 s/step
# Meep progress: 961.1875/1964.306396484375 = 48.9% done in 52.0s, 54.3s to go
# on time step 76925 (time=961.562), 0.000672647 s/step
# Meep progress: 1035.45/1964.306396484375 = 52.7% done in 56.0s, 50.2s to go
# on time step 82867 (time=1035.84), 0.000673249 s/step
# Meep progress: 1109.7625/1964.306396484375 = 56.5% done in 60.0s, 46.2s to go
# on time step 88813 (time=1110.16), 0.000672831 s/step
# Meep progress: 1184.025/1964.306396484375 = 60.3% done in 64.0s, 42.2s to go
# on time step 94755 (time=1184.44), 0.000673251 s/step
# Meep progress: 1258.325/1964.306396484375 = 64.1% done in 68.0s, 38.2s to go
# on time step 100699 (time=1258.74), 0.000672974 s/step
# Meep progress: 1332.575/1964.306396484375 = 67.8% done in 72.0s, 34.1s to go
# on time step 106640 (time=1333), 0.000673347 s/step
# Meep progress: 1406.8875/1964.306396484375 = 71.6% done in 76.0s, 30.1s to go
# on time step 112586 (time=1407.33), 0.000672793 s/step
# Meep progress: 1481.1000000000001/1964.306396484375 = 75.4% done in 80.0s, 26.1s to go
# on time step 118523 (time=1481.54), 0.000673826 s/step
# Meep progress: 1555.3125/1964.306396484375 = 79.2% done in 84.0s, 22.1s to go
# on time step 124460 (time=1555.75), 0.000673781 s/step
# Meep progress: 1629.5/1964.306396484375 = 83.0% done in 88.0s, 18.1s to go
# on time step 130395 (time=1629.94), 0.000673997 s/step
# Meep progress: 1703.6625000000001/1964.306396484375 = 86.7% done in 92.0s, 14.1s to go
# on time step 136328 (time=1704.1), 0.000674202 s/step
# Meep progress: 1777.5875/1964.306396484375 = 90.5% done in 96.0s, 10.1s to go
# on time step 142243 (time=1778.04), 0.000676324 s/step
# Meep progress: 1851.6750000000002/1964.306396484375 = 94.3% done in 100.0s, 6.1s to go
# on time step 148171 (time=1852.14), 0.000674822 s/step
# Meep progress: 1925.75/1964.306396484375 = 98.0% done in 104.0s, 2.1s to go
# on time step 154098 (time=1926.23), 0.000674948 s/step
# run 0 finished at t = 1964.3125 (157145 timesteps)
# data:, xeven, 0.1, 33824026.18632161, 31488654.148668524, -0.9309552320948266
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000703812 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0156021 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.233747 after 27 iters
# Dominant planewave for band 2: (-0.200000,0.000000,0.500000)
# freq:, xodd, 0.15000000000000002, 0.23374670103964204
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00231791 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0311499 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.233747 after 27 iters
# FloatProgress(value=0.0, description='0% done ', max=1927.8135375976562)
# Meep progress: 72.4/1927.8135375976562 = 3.8% done in 4.0s, 102.5s to go
# on time step 5814 (time=72.675), 0.000688001 s/step
# Meep progress: 146.7125/1927.8135375976562 = 7.6% done in 8.0s, 97.1s to go
# on time step 11760 (time=147), 0.000672792 s/step
# Meep progress: 220.97500000000002/1927.8135375976562 = 11.5% done in 12.0s, 92.7s to go
# on time step 17701 (time=221.263), 0.000673299 s/step
# Meep progress: 295.2875/1927.8135375976562 = 15.3% done in 16.0s, 88.5s to go
# on time step 23646 (time=295.575), 0.000672871 s/step
# Meep progress: 369.4375/1927.8135375976562 = 19.2% done in 20.0s, 84.4s to go
# on time step 29578 (time=369.725), 0.000674331 s/step
# Meep progress: 443.76250000000005/1927.8135375976562 = 23.0% done in 24.0s, 80.3s to go
# on time step 35524 (time=444.05), 0.000672758 s/step
# Meep progress: 518.0875/1927.8135375976562 = 26.9% done in 28.0s, 76.2s to go
# on time step 41471 (time=518.388), 0.000672678 s/step
# Meep progress: 592.5625/1927.8135375976562 = 30.7% done in 32.0s, 72.1s to go
# on time step 47430 (time=592.875), 0.000671309 s/step
# Meep progress: 667.0625/1927.8135375976562 = 34.6% done in 36.0s, 68.0s to go
# on time step 53390 (time=667.375), 0.000671236 s/step
# Meep progress: 741.575/1927.8135375976562 = 38.5% done in 40.0s, 64.0s to go
# on time step 59352 (time=741.9), 0.00067102 s/step
# Meep progress: 816.0125/1927.8135375976562 = 42.3% done in 44.0s, 60.0s to go
# on time step 65308 (time=816.35), 0.000671693 s/step
# Meep progress: 890.3875/1927.8135375976562 = 46.2% done in 48.0s, 55.9s to go
# on time step 71258 (time=890.725), 0.000672283 s/step
# Meep progress: 964.825/1927.8135375976562 = 50.0% done in 52.0s, 51.9s to go
# on time step 77213 (time=965.163), 0.000671744 s/step
# Meep progress: 1038.8125/1927.8135375976562 = 53.9% done in 56.0s, 47.9s to go
# on time step 83132 (time=1039.15), 0.00067581 s/step
# Meep progress: 1113.0625/1927.8135375976562 = 57.7% done in 60.0s, 43.9s to go
# on time step 89073 (time=1113.41), 0.000673374 s/step
# Meep progress: 1187.4375/1927.8135375976562 = 61.6% done in 64.0s, 39.9s to go
# on time step 95023 (time=1187.79), 0.000672316 s/step
# Meep progress: 1261.7625/1927.8135375976562 = 65.5% done in 68.0s, 35.9s to go
# on time step 100970 (time=1262.12), 0.000672623 s/step
# Meep progress: 1335.8125/1927.8135375976562 = 69.3% done in 72.0s, 31.9s to go
# on time step 106895 (time=1336.19), 0.000675209 s/step
# Meep progress: 1410.1625000000001/1927.8135375976562 = 73.1% done in 76.0s, 27.9s to go
# on time step 112843 (time=1410.54), 0.00067251 s/step
# Meep progress: 1484.375/1927.8135375976562 = 77.0% done in 80.0s, 23.9s to go
# on time step 118780 (time=1484.75), 0.000673741 s/step
# Meep progress: 1558.4125000000001/1927.8135375976562 = 80.8% done in 84.0s, 19.9s to go
# on time step 124703 (time=1558.79), 0.000675342 s/step
# Meep progress: 1632.6125000000002/1927.8135375976562 = 84.7% done in 88.0s, 15.9s to go
# on time step 130639 (time=1632.99), 0.000673867 s/step
# Meep progress: 1706.775/1927.8135375976562 = 88.5% done in 92.0s, 11.9s to go
# on time step 136572 (time=1707.15), 0.00067423 s/step
# Meep progress: 1780.65/1927.8135375976562 = 92.4% done in 96.0s, 7.9s to go
# on time step 142483 (time=1781.04), 0.000676756 s/step
# Meep progress: 1854.9/1927.8135375976562 = 96.2% done in 100.0s, 3.9s to go
# on time step 148424 (time=1855.3), 0.00067337 s/step
# run 0 finished at t = 1927.825 (154226 timesteps)
# data:, xodd, 0.15000000000000002, 29120077.694126826, -12963207.504569832, 0.445163905149345
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000706911 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.015224 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.217298 after 32 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.15000000000000002, 0.21729769552095704
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00219011 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.035892 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.217298 after 32 iters
# FloatProgress(value=0.0, description='0% done ', max=1960.1981506347656)
# Meep progress: 72.175/1960.1981506347656 = 3.7% done in 4.0s, 104.6s to go
# on time step 5794 (time=72.425), 0.000690457 s/step
# Meep progress: 146.6125/1960.1981506347656 = 7.5% done in 8.0s, 99.0s to go
# on time step 11750 (time=146.875), 0.000671645 s/step
# Meep progress: 220.8625/1960.1981506347656 = 11.3% done in 12.0s, 94.5s to go
# on time step 17691 (time=221.138), 0.000673355 s/step
# Meep progress: 295.08750000000003/1960.1981506347656 = 15.1% done in 16.0s, 90.3s to go
# on time step 23630 (time=295.375), 0.000673623 s/step
# Meep progress: 369.38750000000005/1960.1981506347656 = 18.8% done in 20.0s, 86.1s to go
# on time step 29575 (time=369.688), 0.0006729 s/step
# Meep progress: 443.6/1960.1981506347656 = 22.6% done in 24.0s, 82.1s to go
# on time step 35512 (time=443.9), 0.00067378 s/step
# Meep progress: 517.7625/1960.1981506347656 = 26.4% done in 28.0s, 78.0s to go
# on time step 41445 (time=518.062), 0.000674217 s/step
# Meep progress: 592.025/1960.1981506347656 = 30.2% done in 32.0s, 74.0s to go
# on time step 47386 (time=592.325), 0.0006733 s/step
# Meep progress: 666.1/1960.1981506347656 = 34.0% done in 36.0s, 69.9s to go
# on time step 53313 (time=666.413), 0.000674965 s/step
# Meep progress: 740.4875000000001/1960.1981506347656 = 37.8% done in 40.0s, 65.9s to go
# on time step 59264 (time=740.8), 0.000672165 s/step
# Meep progress: 814.8000000000001/1960.1981506347656 = 41.6% done in 44.0s, 61.9s to go
# on time step 65209 (time=815.113), 0.000672895 s/step
# Meep progress: 889.1500000000001/1960.1981506347656 = 45.4% done in 48.0s, 57.8s to go
# on time step 71157 (time=889.463), 0.00067251 s/step
# Meep progress: 963.4250000000001/1960.1981506347656 = 49.1% done in 52.0s, 53.8s to go
# on time step 77100 (time=963.75), 0.000673166 s/step
# Meep progress: 1037.5375000000001/1960.1981506347656 = 52.9% done in 56.0s, 49.8s to go
# on time step 83030 (time=1037.88), 0.000674614 s/step
# Meep progress: 1111.8875/1960.1981506347656 = 56.7% done in 60.0s, 45.8s to go
# on time step 88979 (time=1112.24), 0.000672466 s/step
# Meep progress: 1186.2875000000001/1960.1981506347656 = 60.5% done in 64.0s, 41.8s to go
# on time step 94932 (time=1186.65), 0.000672005 s/step
# Meep progress: 1260.7875000000001/1960.1981506347656 = 64.3% done in 68.0s, 37.7s to go
# on time step 100892 (time=1261.15), 0.000671189 s/step
# Meep progress: 1334.9750000000001/1960.1981506347656 = 68.1% done in 72.0s, 33.7s to go
# on time step 106828 (time=1335.35), 0.000673906 s/step
# Meep progress: 1409.45/1960.1981506347656 = 71.9% done in 76.0s, 29.7s to go
# on time step 112786 (time=1409.83), 0.000671384 s/step
# Meep progress: 1483.9/1960.1981506347656 = 75.7% done in 80.0s, 25.7s to go
# on time step 118742 (time=1484.28), 0.000671644 s/step
# Meep progress: 1558.3500000000001/1960.1981506347656 = 79.5% done in 84.0s, 21.7s to go
# on time step 124699 (time=1558.74), 0.000671583 s/step
# Meep progress: 1632.775/1960.1981506347656 = 83.3% done in 88.0s, 17.6s to go
# on time step 130653 (time=1633.16), 0.000671861 s/step
# Meep progress: 1707.2/1960.1981506347656 = 87.1% done in 92.0s, 13.6s to go
# on time step 136607 (time=1707.59), 0.000671818 s/step
# Meep progress: 1781.4625/1960.1981506347656 = 90.9% done in 96.0s, 9.6s to go
# on time step 142549 (time=1781.86), 0.000673241 s/step
# Meep progress: 1855.8875/1960.1981506347656 = 94.7% done in 100.0s, 5.6s to go
# on time step 148502 (time=1856.28), 0.000671989 s/step
# Meep progress: 1929.8875/1960.1981506347656 = 98.5% done in 104.0s, 1.6s to go
# on time step 154424 (time=1930.3), 0.000675467 s/step
# run 0 finished at t = 1960.2 (156816 timesteps)
# data:, xeven, 0.15000000000000002, 42990704.035861194, 32213373.97353482, -0.7493102217322065
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000766039 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0201731 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.232876 after 26 iters
# Dominant planewave for band 2: (-0.200000,0.000000,0.500000)
# freq:, xodd, 0.2, 0.23287607652672576
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00230098 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.03146 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.232876 after 26 iters
# FloatProgress(value=0.0, description='0% done ', max=1929.4129333496094)
# Meep progress: 71.4/1929.4129333496094 = 3.7% done in 4.0s, 104.1s to go
# on time step 5734 (time=71.675), 0.000697645 s/step
# Meep progress: 144.7375/1929.4129333496094 = 7.5% done in 8.0s, 98.6s to go
# on time step 11602 (time=145.025), 0.000681745 s/step
# Meep progress: 217.775/1929.4129333496094 = 11.3% done in 12.0s, 94.3s to go
# on time step 17446 (time=218.075), 0.000684585 s/step
# Meep progress: 290.8875/1929.4129333496094 = 15.1% done in 16.0s, 90.1s to go
# on time step 23295 (time=291.188), 0.000683898 s/step
# Meep progress: 364.125/1929.4129333496094 = 18.9% done in 20.0s, 86.0s to go
# on time step 29155 (time=364.438), 0.000682687 s/step
# Meep progress: 437.33750000000003/1929.4129333496094 = 22.7% done in 24.0s, 81.9s to go
# on time step 35012 (time=437.65), 0.000682958 s/step
# Meep progress: 510.45000000000005/1929.4129333496094 = 26.5% done in 28.0s, 77.8s to go
# on time step 40861 (time=510.763), 0.000683909 s/step
# Meep progress: 583.5500000000001/1929.4129333496094 = 30.2% done in 32.0s, 73.8s to go
# on time step 46710 (time=583.875), 0.000683972 s/step
# Meep progress: 656.75/1929.4129333496094 = 34.0% done in 36.0s, 69.8s to go
# on time step 52567 (time=657.088), 0.000683026 s/step
# Meep progress: 730.075/1929.4129333496094 = 37.8% done in 40.0s, 65.7s to go
# on time step 58434 (time=730.425), 0.000681883 s/step
# Meep progress: 803.325/1929.4129333496094 = 41.6% done in 44.0s, 61.7s to go
# on time step 64294 (time=803.675), 0.000682599 s/step
# Meep progress: 876.6/1929.4129333496094 = 45.4% done in 48.0s, 57.7s to go
# on time step 70157 (time=876.963), 0.000682306 s/step
# Meep progress: 949.875/1929.4129333496094 = 49.2% done in 52.0s, 53.6s to go
# on time step 76019 (time=950.238), 0.000682407 s/step
# Meep progress: 1023.1500000000001/1929.4129333496094 = 53.0% done in 56.0s, 49.6s to go
# on time step 81881 (time=1023.51), 0.00068238 s/step
# Meep progress: 1096.4/1929.4129333496094 = 56.8% done in 60.0s, 45.6s to go
# on time step 87741 (time=1096.76), 0.000682645 s/step
# Meep progress: 1169.675/1929.4129333496094 = 60.6% done in 64.0s, 41.6s to go
# on time step 93603 (time=1170.04), 0.000682408 s/step
# Meep progress: 1242.9375/1929.4129333496094 = 64.4% done in 68.0s, 37.6s to go
# on time step 99465 (time=1243.31), 0.000682476 s/step
# Meep progress: 1316.2/1929.4129333496094 = 68.2% done in 72.0s, 33.5s to go
# on time step 105326 (time=1316.58), 0.000682487 s/step
# Meep progress: 1389.45/1929.4129333496094 = 72.0% done in 76.0s, 29.5s to go
# on time step 111187 (time=1389.84), 0.000682488 s/step
# Meep progress: 1462.7625/1929.4129333496094 = 75.8% done in 80.0s, 25.5s to go
# on time step 117052 (time=1463.15), 0.000682049 s/step
# Meep progress: 1535.8500000000001/1929.4129333496094 = 79.6% done in 84.0s, 21.5s to go
# on time step 122900 (time=1536.25), 0.000684023 s/step
# Meep progress: 1609.1375/1929.4129333496094 = 83.4% done in 88.0s, 17.5s to go
# on time step 128763 (time=1609.54), 0.000682293 s/step
# Meep progress: 1682.075/1929.4129333496094 = 87.2% done in 92.0s, 13.5s to go
# on time step 134599 (time=1682.49), 0.00068544 s/step
# Meep progress: 1755.325/1929.4129333496094 = 91.0% done in 96.0s, 9.5s to go
# on time step 140459 (time=1755.74), 0.000682712 s/step
# Meep progress: 1828.4250000000002/1929.4129333496094 = 94.8% done in 100.0s, 5.5s to go
# on time step 146305 (time=1828.81), 0.000684235 s/step
# Meep progress: 1901.3125/1929.4129333496094 = 98.5% done in 104.0s, 1.5s to go
# on time step 152139 (time=1901.74), 0.000685703 s/step
# run 0 finished at t = 1929.4250000000002 (154354 timesteps)
# data:, xodd, 0.2, 29730315.46550725, -12086108.134992812, 0.4065247188182368
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.0007689 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.015228 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.218868 after 33 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.2, 0.21886831081470123
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00237298 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.034209 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.218868 after 33 iters
# FloatProgress(value=0.0, description='0% done ', max=1956.895751953125)
# Meep progress: 72.03750000000001/1956.895751953125 = 3.7% done in 4.0s, 104.7s to go
# on time step 5786 (time=72.325), 0.000691358 s/step
# Meep progress: 146.525/1956.895751953125 = 7.5% done in 8.0s, 98.9s to go
# on time step 11746 (time=146.825), 0.000671244 s/step
# Meep progress: 220.95000000000002/1956.895751953125 = 11.3% done in 12.0s, 94.3s to go
# on time step 17701 (time=221.263), 0.000671788 s/step
# Meep progress: 295.46250000000003/1956.895751953125 = 15.1% done in 16.0s, 90.0s to go
# on time step 23662 (time=295.775), 0.000671064 s/step
# Meep progress: 369.9875/1956.895751953125 = 18.9% done in 20.0s, 85.8s to go
# on time step 29624 (time=370.3), 0.000670949 s/step
# Meep progress: 444.52500000000003/1956.895751953125 = 22.7% done in 24.0s, 81.7s to go
# on time step 35587 (time=444.838), 0.000670834 s/step
# Meep progress: 519.1375/1956.895751953125 = 26.5% done in 28.0s, 77.6s to go
# on time step 41557 (time=519.462), 0.00067012 s/step
# Meep progress: 593.5125/1956.895751953125 = 30.3% done in 32.0s, 73.5s to go
# on time step 47507 (time=593.837), 0.000672315 s/step
# Meep progress: 668.0875000000001/1956.895751953125 = 34.1% done in 36.0s, 69.5s to go
# on time step 53474 (time=668.425), 0.000670439 s/step
# Meep progress: 742.6875/1956.895751953125 = 38.0% done in 40.0s, 65.4s to go
# on time step 59442 (time=743.025), 0.000670288 s/step
# Meep progress: 817.1375/1956.895751953125 = 41.8% done in 44.0s, 61.4s to go
# on time step 65398 (time=817.475), 0.000671606 s/step
# Meep progress: 891.5875000000001/1956.895751953125 = 45.6% done in 48.0s, 57.4s to go
# on time step 71354 (time=891.925), 0.000671602 s/step
# Meep progress: 966.1500000000001/1956.895751953125 = 49.4% done in 52.0s, 53.3s to go
# on time step 77319 (time=966.488), 0.000670596 s/step
# Meep progress: 1040.4375/1956.895751953125 = 53.2% done in 56.0s, 49.3s to go
# on time step 83263 (time=1040.79), 0.000673045 s/step
# Meep progress: 1115.0125/1956.895751953125 = 57.0% done in 60.0s, 45.3s to go
# on time step 89230 (time=1115.38), 0.000670427 s/step
# Meep progress: 1189.65/1956.895751953125 = 60.8% done in 64.0s, 41.3s to go
# on time step 95202 (time=1190.03), 0.000669844 s/step
# Meep progress: 1264.2875000000001/1956.895751953125 = 64.6% done in 68.0s, 37.3s to go
# on time step 101173 (time=1264.66), 0.00066993 s/step
# Meep progress: 1338.6000000000001/1956.895751953125 = 68.4% done in 72.0s, 33.3s to go
# on time step 107118 (time=1338.98), 0.000672862 s/step
# Meep progress: 1413.125/1956.895751953125 = 72.2% done in 76.0s, 29.2s to go
# on time step 113082 (time=1413.53), 0.00067077 s/step
# Meep progress: 1487.6875/1956.895751953125 = 76.0% done in 80.0s, 25.2s to go
# on time step 119047 (time=1488.09), 0.000670614 s/step
# Meep progress: 1562.2375000000002/1956.895751953125 = 79.8% done in 84.0s, 21.2s to go
# on time step 125012 (time=1562.65), 0.000670641 s/step
# Meep progress: 1636.8000000000002/1956.895751953125 = 83.6% done in 88.0s, 17.2s to go
# on time step 130977 (time=1637.21), 0.000670615 s/step
# Meep progress: 1711.3875/1956.895751953125 = 87.5% done in 92.0s, 13.2s to go
# on time step 136944 (time=1711.8), 0.000670399 s/step
# Meep progress: 1786.0125/1956.895751953125 = 91.3% done in 96.0s, 9.2s to go
# on time step 142915 (time=1786.44), 0.000670005 s/step
# Meep progress: 1860.65/1956.895751953125 = 95.1% done in 100.0s, 5.2s to go
# on time step 148886 (time=1861.08), 0.000669925 s/step
# Meep progress: 1935.2875000000001/1956.895751953125 = 98.9% done in 104.0s, 1.2s to go
# on time step 154858 (time=1935.73), 0.000669878 s/step
# run 0 finished at t = 1956.9 (156552 timesteps)
# data:, xeven, 0.2, 48551528.76504878, 29544564.07080183, -0.6085197484465276
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000759125 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.01561 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.232076 after 26 iters
# Dominant planewave for band 2: (-0.200000,0.000000,0.500000)
# freq:, xodd, 0.25, 0.232075759567726
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00229597 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0306299 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.232076 after 26 iters
# FloatProgress(value=0.0, description='0% done ', max=1930.8937683105469)
# Meep progress: 72.4/1930.8937683105469 = 3.7% done in 4.0s, 102.7s to go
# on time step 5815 (time=72.6875), 0.000687952 s/step
# Meep progress: 146.8/1930.8937683105469 = 7.6% done in 8.0s, 97.2s to go
# on time step 11767 (time=147.088), 0.000672098 s/step
# Meep progress: 220.8375/1930.8937683105469 = 11.4% done in 12.0s, 92.9s to go
# on time step 17691 (time=221.138), 0.000675305 s/step
# Meep progress: 295.2375/1930.8937683105469 = 15.3% done in 16.0s, 88.7s to go
# on time step 23644 (time=295.55), 0.000672016 s/step
# Meep progress: 369.46250000000003/1930.8937683105469 = 19.1% done in 20.0s, 84.5s to go
# on time step 29582 (time=369.775), 0.000673741 s/step
# Meep progress: 443.7375/1930.8937683105469 = 23.0% done in 24.0s, 80.4s to go
# on time step 35525 (time=444.062), 0.000673111 s/step
# Meep progress: 518.0875/1930.8937683105469 = 26.8% done in 28.0s, 76.4s to go
# on time step 41474 (time=518.425), 0.000672444 s/step
# Meep progress: 592.325/1930.8937683105469 = 30.7% done in 32.0s, 72.3s to go
# on time step 47414 (time=592.675), 0.000673494 s/step
# Meep progress: 666.6625/1930.8937683105469 = 34.5% done in 36.0s, 68.3s to go
# on time step 53362 (time=667.025), 0.000672548 s/step
# Meep progress: 740.9875000000001/1930.8937683105469 = 38.4% done in 40.0s, 64.2s to go
# on time step 59308 (time=741.35), 0.000672747 s/step
# Meep progress: 815.2625/1930.8937683105469 = 42.2% done in 44.0s, 60.2s to go
# on time step 65251 (time=815.638), 0.000673124 s/step
# Meep progress: 889.5375/1930.8937683105469 = 46.1% done in 48.0s, 56.2s to go
# on time step 71194 (time=889.925), 0.000673139 s/step
# Meep progress: 963.5875000000001/1930.8937683105469 = 49.9% done in 52.0s, 52.2s to go
# on time step 77119 (time=963.988), 0.000675213 s/step
# Meep progress: 1037.9625/1930.8937683105469 = 53.8% done in 56.0s, 48.2s to go
# on time step 83070 (time=1038.38), 0.000672231 s/step
# Meep progress: 1112.2250000000001/1930.8937683105469 = 57.6% done in 60.0s, 44.2s to go
# on time step 89011 (time=1112.64), 0.000673328 s/step
# Meep progress: 1186.525/1930.8937683105469 = 61.4% done in 64.0s, 40.2s to go
# on time step 94956 (time=1186.95), 0.000672907 s/step
# Meep progress: 1260.9250000000002/1930.8937683105469 = 65.3% done in 68.0s, 36.1s to go
# on time step 100908 (time=1261.35), 0.000672066 s/step
# Meep progress: 1335.275/1930.8937683105469 = 69.2% done in 72.0s, 32.1s to go
# on time step 106857 (time=1335.71), 0.000672496 s/step
# Meep progress: 1409.5875/1930.8937683105469 = 73.0% done in 76.0s, 28.1s to go
# on time step 112802 (time=1410.03), 0.000672837 s/step
# Meep progress: 1483.9250000000002/1930.8937683105469 = 76.9% done in 80.0s, 24.1s to go
# on time step 118750 (time=1484.38), 0.000672561 s/step
# Meep progress: 1558.2625/1930.8937683105469 = 80.7% done in 84.0s, 20.1s to go
# on time step 124698 (time=1558.73), 0.000672589 s/step
# Meep progress: 1632.6125000000002/1930.8937683105469 = 84.6% done in 88.0s, 16.1s to go
# on time step 130647 (time=1633.09), 0.000672482 s/step
# Meep progress: 1706.9625/1930.8937683105469 = 88.4% done in 92.0s, 12.1s to go
# on time step 136596 (time=1707.45), 0.000672435 s/step
# Meep progress: 1781.3500000000001/1930.8937683105469 = 92.3% done in 96.0s, 8.1s to go
# on time step 142548 (time=1781.85), 0.000672062 s/step
# Meep progress: 1855.4750000000001/1930.8937683105469 = 96.1% done in 100.0s, 4.1s to go
# on time step 148478 (time=1855.98), 0.000674625 s/step
# Meep progress: 1929.7375000000002/1930.8937683105469 = 99.9% done in 104.0s, 0.1s to go
# on time step 154420 (time=1930.25), 0.000673248 s/step
# run 0 finished at t = 1930.9 (154472 timesteps)
# data:, xodd, 0.25, 30559746.550542463, -11096681.66340276, 0.3631143224650135
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00068903 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.015197 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.220156 after 34 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.25, 0.22015579481100597
# -----------
# Initializing structure...
# Halving computational cell along direction x
# ...
# data:, xodd, 0.9500000000000001, 40721610.985388875, -1778016.868077975, 0.04366273398947641
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000705004 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.015527 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.226021 after 45 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.9500000000000001, 0.22602064762883461
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00229597 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0370789 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.226021 after 45 iters
# FloatProgress(value=0.0, description='0% done ', max=1942.4374694824219)
# Meep progress: 70.91250000000001/1942.4374694824219 = 3.7% done in 4.0s, 105.6s to go
# on time step 5695 (time=71.1875), 0.000702451 s/step
# Meep progress: 144.65/1942.4374694824219 = 7.4% done in 8.0s, 99.4s to go
# on time step 11596 (time=144.95), 0.000677946 s/step
# Meep progress: 218.15/1942.4374694824219 = 11.2% done in 12.0s, 94.9s to go
# on time step 17476 (time=218.45), 0.000680326 s/step
# Meep progress: 291.7625/1942.4374694824219 = 15.0% done in 16.0s, 90.5s to go
# on time step 23366 (time=292.075), 0.000679174 s/step
# Meep progress: 365.625/1942.4374694824219 = 18.8% done in 20.0s, 86.3s to go
# on time step 29276 (time=365.95), 0.000676831 s/step
# Meep progress: 439.3625/1942.4374694824219 = 22.6% done in 24.0s, 82.1s to go
# on time step 35175 (time=439.688), 0.000678138 s/step
# Meep progress: 512.95/1942.4374694824219 = 26.4% done in 28.0s, 78.0s to go
# on time step 41063 (time=513.288), 0.00067946 s/step
# Meep progress: 586.825/1942.4374694824219 = 30.2% done in 32.0s, 73.9s to go
# on time step 46974 (time=587.175), 0.000676775 s/step
# Meep progress: 660.7125000000001/1942.4374694824219 = 34.0% done in 36.0s, 69.8s to go
# on time step 52886 (time=661.075), 0.000676694 s/step
# Meep progress: 734.5875000000001/1942.4374694824219 = 37.8% done in 40.0s, 65.8s to go
# on time step 58796 (time=734.95), 0.000676855 s/step
# Meep progress: 808.4250000000001/1942.4374694824219 = 41.6% done in 44.0s, 61.7s to go
# on time step 64704 (time=808.8), 0.000677147 s/step
# Meep progress: 882.2875/1942.4374694824219 = 45.4% done in 48.0s, 57.7s to go
# on time step 70614 (time=882.675), 0.000676906 s/step
# Meep progress: 956.0500000000001/1942.4374694824219 = 49.2% done in 52.0s, 53.7s to go
# on time step 76515 (time=956.438), 0.000677868 s/step
# Meep progress: 1029.45/1942.4374694824219 = 53.0% done in 56.0s, 49.7s to go
# on time step 82387 (time=1029.84), 0.000681203 s/step
# Meep progress: 1103.025/1942.4374694824219 = 56.8% done in 60.0s, 45.7s to go
# on time step 88274 (time=1103.42), 0.000679547 s/step
# Meep progress: 1176.7250000000001/1942.4374694824219 = 60.6% done in 64.0s, 41.6s to go
# on time step 94171 (time=1177.14), 0.000678369 s/step
# Meep progress: 1250.5625/1942.4374694824219 = 64.4% done in 68.0s, 37.6s to go
# on time step 100079 (time=1250.99), 0.000677146 s/step
# Meep progress: 1324.3500000000001/1942.4374694824219 = 68.2% done in 72.0s, 33.6s to go
# on time step 105982 (time=1324.78), 0.000677625 s/step
# Meep progress: 1397.8375/1942.4374694824219 = 72.0% done in 76.0s, 29.6s to go
# on time step 111861 (time=1398.26), 0.0006804 s/step
# Meep progress: 1471.6625000000001/1942.4374694824219 = 75.8% done in 80.0s, 25.6s to go
# on time step 117768 (time=1472.1), 0.000677217 s/step
# Meep progress: 1545.25/1942.4374694824219 = 79.6% done in 84.0s, 21.6s to go
# on time step 123656 (time=1545.7), 0.000679435 s/step
# Meep progress: 1618.9625/1942.4374694824219 = 83.3% done in 88.0s, 17.6s to go
# on time step 129554 (time=1619.43), 0.000678211 s/step
# Meep progress: 1692.7875000000001/1942.4374694824219 = 87.1% done in 92.0s, 13.6s to go
# on time step 135459 (time=1693.24), 0.000677393 s/step
# Meep progress: 1766.3000000000002/1942.4374694824219 = 90.9% done in 96.0s, 9.6s to go
# on time step 141340 (time=1766.75), 0.000680172 s/step
# Meep progress: 1840.15/1942.4374694824219 = 94.7% done in 100.0s, 5.6s to go
# on time step 147249 (time=1840.61), 0.000677032 s/step
# Meep progress: 1913.8375/1942.4374694824219 = 98.5% done in 104.0s, 1.6s to go
# on time step 153144 (time=1914.3), 0.000678544 s/step
# run 0 finished at t = 1942.4375 (155395 timesteps)
# data:, xeven, 0.9500000000000001, 40447136.318342, 1779898.6461665893, -0.044005554117793985
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000684977 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.015204 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.22728 after 23 iters
# Dominant planewave for band 2: (0.200000,-0.000000,0.500000)
# freq:, xodd, 1.0, 0.22727959569236172
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00241899 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0293269 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.22728 after 23 iters
# FloatProgress(value=0.0, description='0% done ', max=1939.9866943359375)
# Meep progress: 71.775/1939.9866943359375 = 3.7% done in 4.0s, 104.1s to go
# on time step 5764 (time=72.05), 0.000694056 s/step
# Meep progress: 145.4/1939.9866943359375 = 7.5% done in 8.0s, 98.7s to go
# on time step 11655 (time=145.688), 0.000679049 s/step
# Meep progress: 219.16250000000002/1939.9866943359375 = 11.3% done in 12.0s, 94.2s to go
# on time step 17557 (time=219.463), 0.000677819 s/step
# Meep progress: 292.46250000000003/1939.9866943359375 = 15.1% done in 16.0s, 90.1s to go
# on time step 23421 (time=292.762), 0.00068217 s/step
# Meep progress: 365.9875/1939.9866943359375 = 18.9% done in 20.0s, 86.0s to go
# on time step 29303 (time=366.288), 0.000680075 s/step
# Meep progress: 439.38750000000005/1939.9866943359375 = 22.6% done in 24.0s, 82.0s to go
# on time step 35176 (time=439.7), 0.000681137 s/step
# Meep progress: 513.1625/1939.9866943359375 = 26.5% done in 28.0s, 77.9s to go
# on time step 41078 (time=513.475), 0.000677818 s/step
# Meep progress: 586.9125/1939.9866943359375 = 30.3% done in 32.0s, 73.8s to go
# on time step 46979 (time=587.238), 0.000677953 s/step
# Meep progress: 660.6625/1939.9866943359375 = 34.1% done in 36.0s, 69.7s to go
# on time step 52880 (time=661), 0.000677951 s/step
# Meep progress: 734.4375/1939.9866943359375 = 37.9% done in 40.0s, 65.7s to go
# on time step 58782 (time=734.775), 0.000677771 s/step
# Meep progress: 808.2875/1939.9866943359375 = 41.7% done in 44.0s, 61.6s to go
# on time step 64692 (time=808.65), 0.000676921 s/step
# Meep progress: 881.975/1939.9866943359375 = 45.5% done in 48.0s, 57.6s to go
# on time step 70587 (time=882.338), 0.0006786 s/step
# Meep progress: 955.6875/1939.9866943359375 = 49.3% done in 52.0s, 53.6s to go
# on time step 76485 (time=956.062), 0.000678269 s/step
# Meep progress: 1029.0375000000001/1939.9866943359375 = 53.0% done in 56.0s, 49.6s to go
# on time step 82354 (time=1029.42), 0.00068163 s/step
# Meep progress: 1102.675/1939.9866943359375 = 56.8% done in 60.0s, 45.6s to go
# on time step 88246 (time=1103.08), 0.00067898 s/step
# Meep progress: 1176.4375/1939.9866943359375 = 60.6% done in 64.0s, 41.5s to go
# on time step 94147 (time=1176.84), 0.000677856 s/step
# Meep progress: 1250.3625000000002/1939.9866943359375 = 64.5% done in 68.0s, 37.5s to go
# on time step 100062 (time=1250.78), 0.000676316 s/step
# Meep progress: 1324.2375000000002/1939.9866943359375 = 68.3% done in 72.0s, 33.5s to go
# on time step 105972 (time=1324.65), 0.000676838 s/step
# Meep progress: 1397.8875/1939.9866943359375 = 72.1% done in 76.0s, 29.5s to go
# on time step 111865 (time=1398.31), 0.000678813 s/step
# Meep progress: 1471.3625000000002/1939.9866943359375 = 75.8% done in 80.0s, 25.5s to go
# on time step 117743 (time=1471.79), 0.000680551 s/step
# Meep progress: 1545.0375000000001/1939.9866943359375 = 79.6% done in 84.0s, 21.5s to go
# on time step 123638 (time=1545.48), 0.000678593 s/step
# Meep progress: 1618.8000000000002/1939.9866943359375 = 83.4% done in 88.0s, 17.5s to go
# on time step 129539 (time=1619.24), 0.000677894 s/step
# Meep progress: 1692.7/1939.9866943359375 = 87.3% done in 92.0s, 13.4s to go
# on time step 135452 (time=1693.15), 0.000676574 s/step
# Meep progress: 1766.525/1939.9866943359375 = 91.1% done in 96.0s, 9.4s to go
# on time step 141358 (time=1766.98), 0.000677299 s/step
# Meep progress: 1840.3375/1939.9866943359375 = 94.9% done in 100.0s, 5.4s to go
# on time step 147264 (time=1840.8), 0.000677337 s/step
# Meep progress: 1913.9750000000001/1939.9866943359375 = 98.7% done in 104.0s, 1.4s to go
# on time step 153155 (time=1914.44), 0.000679028 s/step
# run 0 finished at t = 1939.9875000000002 (155199 timesteps)
# data:, xodd, 1.0, 41078723.17255323, -1539710.970973788, 0.037481957861887655
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000760078 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.015451 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.226111 after 45 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 1.0, 0.2261111518031121
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00246596 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.034003 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.226111 after 45 iters
# FloatProgress(value=0.0, description='0% done ', max=1942.2603759765625)
# Meep progress: 71.66250000000001/1942.2603759765625 = 3.7% done in 4.0s, 104.4s to go
# on time step 5756 (time=71.95), 0.000695027 s/step
# Meep progress: 145.5/1942.2603759765625 = 7.5% done in 8.0s, 98.8s to go
# on time step 11663 (time=145.787), 0.00067717 s/step
# Meep progress: 219.26250000000002/1942.2603759765625 = 11.3% done in 12.0s, 94.3s to go
# on time step 17564 (time=219.55), 0.00067786 s/step
# Meep progress: 293.2/1942.2603759765625 = 15.1% done in 16.0s, 90.0s to go
# on time step 23479 (time=293.488), 0.000676276 s/step
# Meep progress: 367.08750000000003/1942.2603759765625 = 18.9% done in 20.0s, 85.8s to go
# on time step 29391 (time=367.388), 0.00067667 s/step
# Meep progress: 440.85/1942.2603759765625 = 22.7% done in 24.0s, 81.7s to go
# on time step 35292 (time=441.15), 0.000677911 s/step
# Meep progress: 514.525/1942.2603759765625 = 26.5% done in 28.0s, 77.7s to go
# on time step 41187 (time=514.837), 0.000678604 s/step
# Meep progress: 588.4875000000001/1942.2603759765625 = 30.3% done in 32.0s, 73.6s to go
# on time step 47105 (time=588.812), 0.000675977 s/step
# Meep progress: 662.4875000000001/1942.2603759765625 = 34.1% done in 36.0s, 69.5s to go
# on time step 53025 (time=662.812), 0.000675712 s/step
# Meep progress: 735.9375/1942.2603759765625 = 37.9% done in 40.0s, 65.6s to go
# on time step 58902 (time=736.275), 0.000680693 s/step
# Meep progress: 809.575/1942.2603759765625 = 41.7% done in 44.0s, 61.6s to go
# on time step 64793 (time=809.913), 0.000679013 s/step
# Meep progress: 883.4250000000001/1942.2603759765625 = 45.5% done in 48.0s, 57.5s to go
# on time step 70702 (time=883.775), 0.000677002 s/step
# Meep progress: 957.2875/1942.2603759765625 = 49.3% done in 52.0s, 53.5s to go
# on time step 76611 (time=957.638), 0.000676952 s/step
# Meep progress: 1030.9750000000001/1942.2603759765625 = 53.1% done in 56.0s, 49.5s to go
# on time step 82506 (time=1031.33), 0.000678551 s/step
# Meep progress: 1104.675/1942.2603759765625 = 56.9% done in 60.0s, 45.5s to go
# on time step 88403 (time=1105.04), 0.000678402 s/step
# Meep progress: 1178.525/1942.2603759765625 = 60.7% done in 64.0s, 41.5s to go
# on time step 94312 (time=1178.9), 0.000677045 s/step
# Meep progress: 1252.5125/1942.2603759765625 = 64.5% done in 68.0s, 37.4s to go
# on time step 100232 (time=1252.9), 0.000675722 s/step
# Meep progress: 1326.5125/1942.2603759765625 = 68.3% done in 72.0s, 33.4s to go
# on time step 106152 (time=1326.9), 0.000675714 s/step
# Meep progress: 1400.3875/1942.2603759765625 = 72.1% done in 76.0s, 29.4s to go
# on time step 112063 (time=1400.79), 0.000676822 s/step
# Meep progress: 1473.9/1942.2603759765625 = 75.9% done in 80.0s, 25.4s to go
# on time step 117945 (time=1474.31), 0.000680137 s/step
# Meep progress: 1547.7250000000001/1942.2603759765625 = 79.7% done in 84.0s, 21.4s to go
# on time step 123851 (time=1548.14), 0.000677306 s/step
# Meep progress: 1621.4875000000002/1942.2603759765625 = 83.5% done in 88.0s, 17.4s to go
# on time step 129752 (time=1621.9), 0.000677855 s/step
# Meep progress: 1695.2625/1942.2603759765625 = 87.3% done in 92.0s, 13.4s to go
# on time step 135654 (time=1695.68), 0.000677756 s/step
# Meep progress: 1768.5125/1942.2603759765625 = 91.1% done in 96.0s, 9.4s to go
# on time step 141514 (time=1768.93), 0.000682649 s/step
# Meep progress: 1842.2625/1942.2603759765625 = 94.9% done in 100.0s, 5.4s to go
# on time step 147416 (time=1842.7), 0.000677818 s/step
# Meep progress: 1916.15/1942.2603759765625 = 98.7% done in 104.0s, 1.4s to go
# on time step 153327 (time=1916.59), 0.000676723 s/step
# run 0 finished at t = 1942.2625 (155381 timesteps)
# data:, xeven, 1.0, 39474066.30653911, 1473027.8174006322, -0.037316343494022464
